# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.imdb.com/chart/top/?ref_=hm_nv_menu&view=grid').text
webpage

# %%
print(webpage)
