# %%
import pandas as pd 
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/trending/all/day?api_key=5914f7585eebb7f0daaeb19e48d0cde5")

# %%
df = pd.DataFrame(response.json()['results'])
